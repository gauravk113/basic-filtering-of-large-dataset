# %%
import pandas as pd

import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-65e399c9-4c06-43b6-8bf9-5753cbae6052" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65e399c9-4c06-43b6-8bf9-5753cbae6052">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded["parents_mediatype.csv"]))
df
# Out:
#         from_parent   shortdate          date      time message_type  \
# 0              True  01-05-2021   01 May 2021  06:26:00        Image
# 1              True  01-05-2021   01 May 2021  06:44:00         Chat
# 2              True  01-05-2021   01 May 2021  07:25:00         Chat
# 3              True  01-05-2021   01 May 2021  07:26:00        Image
# 4              True  01-05-2021   01 May 2021  07:28:00        Image
# ...             ...         ...           ...       ...          ...
# 111900         True  09-06-2021  09 June 2021  21:10:00        Video
# 111901         True  09-06-2021  09 June 2021  21:11:00        Video
# 111902         True  09-06-2021  09 June 2021  21:12:00         Chat
# 111903         True  09-06-2021  09 June 2021  21:12:00        Video
# 111904         True  09-06-2021  09 June 2021  21:12:00        Video
#
#        whatsapp_uid    parent_ID    group_ID    school_ID
# 0               w_1      parent1     group_1     school_1
# ...

# %%
#filteringmedia
filt = ((df['message_type'] == 'Image') | (df['message_type'] == 'Video')) 

df1 = df[filt]

# %%
df1
# Out:
#         from_parent   shortdate          date      time message_type  \
# 0              True  01-05-2021   01 May 2021  06:26:00        Image
# 3              True  01-05-2021   01 May 2021  07:26:00        Image
# 4              True  01-05-2021   01 May 2021  07:28:00        Image
# 5              True  01-05-2021   01 May 2021  07:28:00        Image
# 6              True  01-05-2021   01 May 2021  07:37:00        Video
# ...             ...         ...           ...       ...          ...
# 111899         True  09-06-2021  09 June 2021  21:10:00        Video
# 111900         True  09-06-2021  09 June 2021  21:10:00        Video
# 111901         True  09-06-2021  09 June 2021  21:11:00        Video
# 111903         True  09-06-2021  09 June 2021  21:12:00        Video
# 111904         True  09-06-2021  09 June 2021  21:12:00        Video
#
#        whatsapp_uid    parent_ID    group_ID    school_ID
# 0               w_1      parent1     group_1     school_1
# ...

# %%
df1.to_csv('parent_media_daily.csv')

# %%
from google.colab import files
files.download("parent_media_daily.csv")

# %%
#sortingbydate
df2 = df1.sort_values(by=['date'])

# %%
df2
# Out:
#        from_parent   shortdate          date      time message_type  \
# 69826         True  01-06-2021  01 June 2021  15:54:00        Image
# 69463         True  01-06-2021  01 June 2021  14:31:00        Video
# 69464         True  01-06-2021  01 June 2021  14:31:00        Image
# 69465         True  01-06-2021  01 June 2021  14:31:00        Video
# 69466         True  01-06-2021  01 June 2021  14:31:00        Video
# ...            ...         ...           ...       ...          ...
# 66001         True  31-05-2021   31 May 2021  14:54:00        Image
# 66000         True  31-05-2021   31 May 2021  14:54:00        Image
# 65997         True  31-05-2021   31 May 2021  14:53:00        Video
# 66014         True  31-05-2021   31 May 2021  14:58:00        Image
# 65776         True  31-05-2021   31 May 2021  12:50:00        Video
#
#       whatsapp_uid   parent_ID    group_ID    school_ID
# 69826      w_69018  parent4737  group_1017   school_941
# ...

# %%
#sortingbydate&time
df3 = df1.sort_values(by=['date', 'time'],
               ascending=[True, True])

# %%
df3
# Out:
#        from_parent   shortdate          date      time message_type  \
# 67749         True  01-06-2021  01 June 2021  00:00:00        Image
# 67750         True  01-06-2021  01 June 2021  00:00:00        Video
# 67752         True  01-06-2021  01 June 2021  00:01:00        Image
# 67753         True  01-06-2021  01 June 2021  00:05:00        Image
# 67755         True  01-06-2021  01 June 2021  00:14:00        Video
# ...            ...         ...           ...       ...          ...
# 67744         True  31-05-2021   31 May 2021  23:55:00        Image
# 67745         True  31-05-2021   31 May 2021  23:55:00        Image
# 67746         True  31-05-2021   31 May 2021  23:56:00        Image
# 67747         True  31-05-2021   31 May 2021  23:57:00        Image
# 67748         True  31-05-2021   31 May 2021  23:58:00        Image
#
#       whatsapp_uid   parent_ID    group_ID    school_ID
# 67749      w_66508  parent9053  group_1976  school_1750
# ...

# %%
df1['date']= pd.to_datetime(df1['date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#         from_parent   shortdate       date      time message_type  \
# 0              True  01-05-2021 2021-05-01  06:26:00        Image
# 3              True  01-05-2021 2021-05-01  07:26:00        Image
# 4              True  01-05-2021 2021-05-01  07:28:00        Image
# 5              True  01-05-2021 2021-05-01  07:28:00        Image
# 6              True  01-05-2021 2021-05-01  07:37:00        Video
# ...             ...         ...        ...       ...          ...
# 111899         True  09-06-2021 2021-06-09  21:10:00        Video
# 111900         True  09-06-2021 2021-06-09  21:10:00        Video
# 111901         True  09-06-2021 2021-06-09  21:11:00        Video
# 111903         True  09-06-2021 2021-06-09  21:12:00        Video
# 111904         True  09-06-2021 2021-06-09  21:12:00        Video
#
#        whatsapp_uid    parent_ID    group_ID    school_ID
# 0               w_1      parent1     group_1     school_1
# ...

# %%
df1
# Out:
#         from_parent   shortdate       date      time message_type  \
# 0              True  01-05-2021 2021-05-01  06:26:00        Image
# 3              True  01-05-2021 2021-05-01  07:26:00        Image
# 4              True  01-05-2021 2021-05-01  07:28:00        Image
# 5              True  01-05-2021 2021-05-01  07:28:00        Image
# 6              True  01-05-2021 2021-05-01  07:37:00        Video
# ...             ...         ...        ...       ...          ...
# 111899         True  09-06-2021 2021-06-09  21:10:00        Video
# 111900         True  09-06-2021 2021-06-09  21:10:00        Video
# 111901         True  09-06-2021 2021-06-09  21:11:00        Video
# 111903         True  09-06-2021 2021-06-09  21:12:00        Video
# 111904         True  09-06-2021 2021-06-09  21:12:00        Video
#
#        whatsapp_uid    parent_ID    group_ID    school_ID
# 0               w_1      parent1     group_1     school_1
# ...

# %%
#filteringweek
#filt2 = ((df1['date'] >= '2021-05-01 00:00:00') | (df1['date'] <= '2021-05-07 00:00:00')) 

df1_week1 = df1[filt2]

# %%
#df1_week1
# Out:
#         from_parent   shortdate       date      time message_type  \
# 0              True  01-05-2021 2021-05-01  06:26:00        Image
# 3              True  01-05-2021 2021-05-01  07:26:00        Image
# 4              True  01-05-2021 2021-05-01  07:28:00        Image
# 5              True  01-05-2021 2021-05-01  07:28:00        Image
# 6              True  01-05-2021 2021-05-01  07:37:00        Video
# ...             ...         ...        ...       ...          ...
# 111899         True  09-06-2021 2021-06-09  21:10:00        Video
# 111900         True  09-06-2021 2021-06-09  21:10:00        Video
# 111901         True  09-06-2021 2021-06-09  21:11:00        Video
# 111903         True  09-06-2021 2021-06-09  21:12:00        Video
# 111904         True  09-06-2021 2021-06-09  21:12:00        Video
#
#        whatsapp_uid    parent_ID    group_ID    school_ID
# 0               w_1      parent1     group_1     school_1
# ...

# %%
#filteringweek1
filtered_df = df1.loc[(df1['date'] >= '2021-05-01')
                     & (df1['date'] <= '2021-05-07')]

# %%
filtered_df
# Out:
#       from_parent   shortdate       date      time message_type whatsapp_uid  \
# 0            True  01-05-2021 2021-05-01  06:26:00        Image          w_1
# 3            True  01-05-2021 2021-05-01  07:26:00        Image         w_70
# 4            True  01-05-2021 2021-05-01  07:28:00        Image         w_69
# 5            True  01-05-2021 2021-05-01  07:28:00        Image        w_152
# 6            True  01-05-2021 2021-05-01  07:37:00        Video        w_148
# ...           ...         ...        ...       ...          ...          ...
# 3228         True  07-05-2021 2021-05-07  22:16:00        Image       w_2956
# 3233         True  07-05-2021 2021-05-07  22:23:00        Image       w_2961
# 3236         True  07-05-2021 2021-05-07  22:27:00        Video       w_2964
# 3238         True  07-05-2021 2021-05-07  23:06:00        Video       w_2966
# 3239         True  07-05-2021 2021-05-07  23:38:00        Image       w_2967
#
#        parent_ID   group_ID   school_ID
# ...

# %%
filtered_df.to_csv('parentsmedia_week1.csv')

# %%
from google.colab import files
files.download("parentsmedia_week1.csv")

# %%
#filteringweek2
filtered_df2 = df1.loc[(df1['date'] >= '2021-05-08')
                     & (df1['date'] <= '2021-05-15')]

# %%
filtered_df2
# Out:
#        from_parent   shortdate       date      time message_type whatsapp_uid  \
# 3246          True  08-05-2021 2021-05-08  04:03:00        Video       w_2972
# 3248          True  08-05-2021 2021-05-08  05:14:00        Video       w_2976
# 3249          True  08-05-2021 2021-05-08  05:18:00        Video       w_2975
# 3251          True  08-05-2021 2021-05-08  05:19:00        Video       w_2974
# 3252          True  08-05-2021 2021-05-08  05:24:00        Video       w_2977
# ...            ...         ...        ...       ...          ...          ...
# 13485         True  15-05-2021 2021-05-15  23:09:00        Video      w_12473
# 13486         True  15-05-2021 2021-05-15  23:23:00        Image      w_12474
# 13487         True  15-05-2021 2021-05-15  23:28:00        Image      w_12475
# 13488         True  15-05-2021 2021-05-15  23:37:00        Image      w_12476
# 13489         True  15-05-2021 2021-05-15  23:37:00        Image      w_12477
#
# ...

# %%
filtered_df2.to_csv('parentsmedia_week2.csv')

# %%
from google.colab import files
files.download("parentsmedia_week2.csv")

# %%
#filteringweek3
filtered_df3 = df1.loc[(df1['date'] >= '2021-05-16')
                     & (df1['date'] <= '2021-05-23')]

# %%
filtered_df3
# Out:
#        from_parent   shortdate       date      time message_type whatsapp_uid  \
# 13490         True  16-05-2021 2021-05-16  00:00:00        Video      w_12478
# 13492         True  16-05-2021 2021-05-16  00:19:00        Video      w_12479
# 13493         True  16-05-2021 2021-05-16  01:08:00        Video      w_12513
# 13496         True  16-05-2021 2021-05-16  03:00:00        Video      w_12692
# 13499         True  16-05-2021 2021-05-16  04:27:00        Video      w_12695
# ...            ...         ...        ...       ...          ...          ...
# 35502         True  23-05-2021 2021-05-23  23:03:00        Video      w_34502
# 35511         True  23-05-2021 2021-05-23  23:15:00        Video      w_34513
# 35512         True  23-05-2021 2021-05-23  23:16:00        Video      w_34514
# 35515         True  23-05-2021 2021-05-23  23:30:00        Image      w_34517
# 35519         True  23-05-2021 2021-05-23  23:38:00        Video      w_34521
#
# ...

# %%
filtered_df3.to_csv('parentsmedia_week3.csv')

# %%
from google.colab import files
files.download("parentsmedia_week3.csv")

# %%
#filteringweek4
filtered_df4 = df1.loc[(df1['date'] >= '2021-05-24')
                     & (df1['date'] <= '2021-05-31')]

# %%
filtered_df4
# Out:
#        from_parent   shortdate       date      time message_type whatsapp_uid  \
# 35526         True  24-05-2021 2021-05-24  01:09:00        Image      w_34527
# 35527         True  24-05-2021 2021-05-24  01:09:00        Video      w_34528
# 35529         True  24-05-2021 2021-05-24  01:16:00        Video      w_34530
# 35531         True  24-05-2021 2021-05-24  01:29:00        Video      w_34532
# 35532         True  24-05-2021 2021-05-24  01:31:00        Video      w_34533
# ...            ...         ...        ...       ...          ...          ...
# 67744         True  31-05-2021 2021-05-31  23:55:00        Image      w_66503
# 67745         True  31-05-2021 2021-05-31  23:55:00        Image      w_66504
# 67746         True  31-05-2021 2021-05-31  23:56:00        Image      w_66505
# 67747         True  31-05-2021 2021-05-31  23:57:00        Image      w_66506
# 67748         True  31-05-2021 2021-05-31  23:58:00        Image      w_66507
#
# ...

# %%
filtered_df4.to_csv('parentsmedia_week4.csv')

# %%
from google.colab import files
files.download("parentsmedia_week4.csv")

# %%
#filteringweek5
filtered_df5 = df1.loc[(df1['date'] >= '2021-06-01')
                     & (df1['date'] <= '2021-06-09')]

# %%
filtered_df5
# Out:
#         from_parent   shortdate       date      time message_type  \
# 67749          True  01-06-2021 2021-06-01  00:00:00        Image
# 67750          True  01-06-2021 2021-06-01  00:00:00        Video
# 67752          True  01-06-2021 2021-06-01  00:01:00        Image
# 67753          True  01-06-2021 2021-06-01  00:05:00        Image
# 67755          True  01-06-2021 2021-06-01  00:14:00        Video
# ...             ...         ...        ...       ...          ...
# 111899         True  09-06-2021 2021-06-09  21:10:00        Video
# 111900         True  09-06-2021 2021-06-09  21:10:00        Video
# 111901         True  09-06-2021 2021-06-09  21:11:00        Video
# 111903         True  09-06-2021 2021-06-09  21:12:00        Video
# 111904         True  09-06-2021 2021-06-09  21:12:00        Video
#
#        whatsapp_uid    parent_ID    group_ID    school_ID
# 67749       w_66508   parent9053  group_1976  school_1750
# ...

# %%
filtered_df5.to_csv('parentsmedia_week5.csv')

# %%
from google.colab import files
files.download("parentsmedia_week5.csv")

# %%
#convertedintodateobjects
df['DATE'] = df1.date.dt.date
df['YEAR'] = df1.date.dt.year
df['MONTH'] = df1.date.dt.month
df['WEEK'] = df1.date.dt.week
df['DAY_OF_WEEK'] = df1.date.dt.day_name()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   after removing the cwd from sys.path.

# %%
df_date = df.groupby('DATE')
df_date.describe()
# Out:
#               YEAR                                                       \
#              count    mean  std     min     25%     50%     75%     max
# DATE
# 2021-05-01    33.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-02    76.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-03   160.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-04   274.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-05   351.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-06   381.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-07   339.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-08   382.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-09   479.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-10   450.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# 2021-05-11   619.0  2021.0  0.0  2021.0  2021.0  2021.0  2021.0  2021.0
# ...

# %%
#dailycountofmedia
count_daily = df_date.count()['message_type']

# %%
count_daily
# Out:
# DATE
# 2021-05-01      33
# 2021-05-02      76
# 2021-05-03     160
# 2021-05-04     274
# 2021-05-05     351
# 2021-05-06     381
# 2021-05-07     339
# 2021-05-08     382
# 2021-05-09     479
# 2021-05-10     450
# 2021-05-11     619
# 2021-05-12     950
# 2021-05-13     753
# 2021-05-14     952
# 2021-05-15     889
# 2021-05-16     765
# 2021-05-17    1059
# 2021-05-18    2069
# 2021-05-19    2016
# 2021-05-20    2610
# 2021-05-21    2328
# 2021-05-22    2483
# 2021-05-23    2172
# 2021-05-24    4703
# 2021-05-25    2697
# 2021-05-26    2296
# 2021-05-27    2654
# 2021-05-28    2037
# 2021-05-29    2497
# 2021-05-30    3461
# 2021-05-31    1608
# 2021-06-01    2819
# 2021-06-02    2399
# 2021-06-03    5107
# 2021-06-04    4764
# 2021-06-05    4792
# 2021-06-06    2633
# 2021-06-07    2362
# 2021-06-08    1705
# 2021-06-09    3685
# Name: message_type, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
#matplotlibplotofmedia
fig, ax = plt.subplots(1, figsize=(12,6))
plt.plot(count_daily.index, count_daily.values)
plt.show()

# %%
# Out:
#   File "<ipython-input-61-7c5e69cac86c>", line 1
#     df_week = df.groupby('WEEK'])
#                                ^
# SyntaxError: invalid syntax
